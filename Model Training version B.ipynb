# %% [markdown]
# ## Model Training
#
# We'll attempt to train a multi-class support vector machine on our feature-engineered data.

# %% [markdown]
# ### Retrieve feature-engineered data into pandas dataframe

# %%
import config
import mysql
import mysql.connector
from mysql.connector import errorcode

# DB FUNCTIONS

def connect(db_name=None):
    if db_name:
        cnx = mysql.connector.connect(
            host = config.rds_host,
            user = config.rds_user,
            passwd = config.rds_password,
            database = db_name)
    else:
        cnx = mysql.connector.connect(
            host = config.rds_host,
            user = config.rds_user,
            passwd = config.rds_password)
    cursor = cnx.cursor()
    return cursor, cnx

# %%
import pandas as pd

cur, cnx = connect('instruments')
cur.execute('''SELECT * FROM harmonic_content''')

df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
cnx.close()

# %%
df
# Out:
#          sample_id  frequency_id  amplitude
# 0                1             0   0.003238
# 1                1             1   0.003516
# 2                1             2   0.003653
# 3                1             3   0.004583
# 4                1             4   0.005378
# ...            ...           ...        ...
# 4786171       1847          2043   0.002954
# 4786172       1847          2044   0.002266
# 4786173       1847          2045   0.002954
# 4786174       1847          2046   0.001999
# 4786175       1847          2047   0.002873
#
# [4786176 rows x 3 columns]

# %%
data = df.pivot(index='sample_id', columns='frequency_id', values='amplitude')
data
# Out:
# frequency_id      0         1         2         3         4         5     \
# sample_id
# 1             0.003238  0.003516  0.003653  0.004583  0.005378  0.005542
# 2             0.002859  0.004412  0.006860  0.010949  0.013922  0.015170
# 3             0.470771  0.314912  0.120817  0.095654  0.085359  0.060197
# 4             0.005541  0.009706  0.013444  0.023435  0.032274  0.034287
# 5             0.003521  0.003417  0.003128  0.003775  0.003662  0.004113
# ...                ...       ...       ...       ...       ...       ...
# 2333          0.005842  0.006696  0.005504  0.008009  0.010848  0.008933
# 2334          0.011724  0.013896  0.011100  0.013689  0.022415  0.020919
# 2335          0.014983  0.020384  0.016735  0.018972  0.027308  0.021950
# 2336          0.010699  0.013480  0.009601  0.013410  0.019354  0.015173
# 2337          0.006926  0.009703  0.008818  0.009757  0.013330  0.012555
#
# frequency_id      6         7         8         9     ...      2038      2039  \
# sample_id                                             ...
# 1             0.005779  0.005876  0.006885  0.006476  ...  0.076767  0.073233
# 2             0.017266  0.020821  0.021021  0.021095  ...  0.060817  0.060192
# 3             0.037835  0.032554  0.027049  0.026489  ...  0.003026  0.002823
# 4             0.033264  0.040268  0.040223  0.034025  ...  0.041233  0.033820
# 5             0.004573  0.005411  0.006391  0.005843  ...  0.042432  0.043850
# ...                ...       ...       ...       ...  ...       ...       ...
# 2333          0.005405  0.005450  0.004055  0.004462  ...  0.000296  0.000293
# 2334          0.010713  0.008141  0.006795  0.008993  ...  0.000432  0.000410
# 2335          0.012783  0.012019  0.008091  0.008059  ...  0.000304  0.000357
# 2336          0.010070  0.008354  0.005919  0.008271  ...  0.000284  0.000300
# 2337          0.009521  0.008093  0.004711  0.004717  ...  0.003592  0.003575
#
# frequency_id      2040      2041      2042      2043      2044      2045  \
# sample_id
# 1             0.073390  0.071249  0.067423  0.074807  0.071793  0.074314
# 2             0.063314  0.061040  0.062658  0.058267  0.060641  0.061230
# 3             0.002957  0.003481  0.003591  0.003186  0.003226  0.003548
# 4             0.032133  0.029678  0.030990  0.035940  0.036911  0.036216
# 5             0.041825  0.037201  0.036231  0.039358  0.046034  0.049473
# ...                ...       ...       ...       ...       ...       ...
# 2333          0.000254  0.000225  0.000219  0.000230  0.000214  0.000199
# 2334          0.000409  0.000413  0.000424  0.000351  0.000316  0.000306
# 2335          0.000451  0.000693  0.000934  0.000752  0.000527  0.000734
# 2336          0.000307  0.000298  0.000252  0.000240  0.000230  0.000376
# 2337          0.003533  0.003810  0.003701  0.002575  0.001704  0.002608
#
# frequency_id      2046      2047
# sample_id
# 1             0.065015  0.060249
# 2             0.057176  0.052379
# 3             0.003635  0.003283
# 4             0.038078  0.038489
# 5             0.047220  0.040782
# ...                ...       ...
# 2333          0.000189  0.000159
# 2334          0.000334  0.000327
# 2335          0.000921  0.000812
# 2336          0.000763  0.000884
# 2337          0.002256  0.002865
#
# [2337 rows x 2048 columns]

# %%
import pandas as pd

cur, cnx = connect('instruments')
cur.execute('''SELECT * FROM samples''')

sample_info = pd.DataFrame(cur.fetchall())
sample_info.columns = [i[0] for i in cur.description]
cnx.close()

# %%
sample_info.set_index('sample_id', inplace=True)
sample_info.sample(5)
# Out:
#           instrument_name note expression    source file_extension
# sample_id
# 2039           Vibraphone   E5    sustain  Iowa2012            aif
# 1611              Marimba  Db4       cord  Iowa2012            aif
# 1550              Marimba  Gb5       roll  Iowa2012            aif
# 46                  Flute   E4     nonvib  Iowa2012            aif
# 2215           Vibraphone  Eb6        bow  Iowa2012            aif

# %%
data2 = data.join(sample_info)
data2
# Out:
#                   0         1         2         3         4         5  \
# sample_id
# 1          0.003238  0.003516  0.003653  0.004583  0.005378  0.005542
# 2          0.002859  0.004412  0.006860  0.010949  0.013922  0.015170
# 3          0.470771  0.314912  0.120817  0.095654  0.085359  0.060197
# 4          0.005541  0.009706  0.013444  0.023435  0.032274  0.034287
# 5          0.003521  0.003417  0.003128  0.003775  0.003662  0.004113
# ...             ...       ...       ...       ...       ...       ...
# 2333       0.005842  0.006696  0.005504  0.008009  0.010848  0.008933
# 2334       0.011724  0.013896  0.011100  0.013689  0.022415  0.020919
# 2335       0.014983  0.020384  0.016735  0.018972  0.027308  0.021950
# 2336       0.010699  0.013480  0.009601  0.013410  0.019354  0.015173
# 2337       0.006926  0.009703  0.008818  0.009757  0.013330  0.012555
#
#                   6         7         8         9  ...      2043      2044  \
# sample_id                                          ...
# 1          0.005779  0.005876  0.006885  0.006476  ...  0.074807  0.071793
# 2          0.017266  0.020821  0.021021  0.021095  ...  0.058267  0.060641
# 3          0.037835  0.032554  0.027049  0.026489  ...  0.003186  0.003226
# 4          0.033264  0.040268  0.040223  0.034025  ...  0.035940  0.036911
# 5          0.004573  0.005411  0.006391  0.005843  ...  0.039358  0.046034
# ...             ...       ...       ...       ...  ...       ...       ...
# 2333       0.005405  0.005450  0.004055  0.004462  ...  0.000230  0.000214
# 2334       0.010713  0.008141  0.006795  0.008993  ...  0.000351  0.000316
# 2335       0.012783  0.012019  0.008091  0.008059  ...  0.000752  0.000527
# 2336       0.010070  0.008354  0.005919  0.008271  ...  0.000240  0.000230
# 2337       0.009521  0.008093  0.004711  0.004717  ...  0.002575  0.001704
#
#                2045      2046      2047  instrument_name  note  expression  \
# sample_id
# 1          0.074314  0.065015  0.060249            Flute   Gb6         vib
# 2          0.061230  0.057176  0.052379            Flute   Bb5         vib
# 3          0.003548  0.003635  0.003283            Flute    G4         vib
# 4          0.036216  0.038078  0.038489            Flute   Eb5         vib
# 5          0.049473  0.047220  0.040782            Flute    A6         vib
# ...             ...       ...       ...              ...   ...         ...
# 2333       0.000199  0.000189  0.000159          Crotale   Gb6
# 2334       0.000306  0.000334  0.000327          Crotale    A7
# 2335       0.000734  0.000921  0.000812          Crotale    E6
# 2336       0.000376  0.000763  0.000884          Crotale   Ab6
# 2337       0.002608  0.002256  0.002865          Crotale    D7
#
#              source  file_extension
# sample_id
# 1          Iowa2012             aif
# 2          Iowa2012             aif
# 3          Iowa2012             aif
# 4          Iowa2012             aif
# 5          Iowa2012             aif
# ...             ...             ...
# 2333       Iowa2012             aif
# 2334       Iowa2012             aif
# 2335       Iowa2012             aif
# 2336       Iowa2012             aif
# 2337       Iowa2012             aif
#
# [2337 rows x 2053 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
from sklearn import svm
from sklearn.model_selection import train_test_split

import numpy as np

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

# %%
rfc = RFC(criterion='gini', n_estimators=50, min_impurity_decrease=0.1, max_depth=4, max_features=3)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel='rbf', gamma='scale')

# %%
X = data2[list(range(2047))]
y = data2['instrument_name']

# %%
from sklearn import decomposition

np.random.seed(5)

pca = decomposition.PCA(n_components=3)
pca.fit(X)
X2 = pca.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.2)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=3, max_leaf_nodes=None,
#                        min_impurity_decrease=0.1, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
svc.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = svc.predict(X_test)

# %%
y_pred = rfc.predict(X_test)

# %%
y_train
# Out:
# sample_id
# 1301       Bass
# 1532    Marimba
# 1463       Bass
# 420      SopSax
# 1335       Bass
#          ...
# 1375       Bass
# 1620    Marimba
# 548     Trumpet
# 1442       Bass
# 343     Bassoon
# Name: instrument_name, Length: 1869, dtype: object

# %%
results = list(zip(list(y_pred), list(y_train)))

# %%
len([x for x in results if x[0]==x[1]]) / len(results)
# Out:
# 0.13034188034188035

# %%
results
# Out:
# [('Cello', 'Violin'),
#  ('Marimba', 'Vibraphone'),
#  ('Bass', 'BbClarinet'),
#  ('Marimba', 'BassClarinet'),
#  ('Bass', 'Marimba'),
#  ('Marimba', 'Flute'),
#  ('Xylophone', 'Tuba'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'SopSax'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Violin'),
#  ('AltoSax', 'Vibraphone'),
#  ('Marimba', 'Flute'),
#  ('Xylophone', 'BbClarinet'),
#  ('AltoSax', 'Marimba'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Xylophone'),
#  ('Tuba', 'Tuba'),
#  ('Bass', 'Viola'),
#  ('Marimba', 'Trumpet'),
#  ('Marimba', 'Marimba'),
#  ('Vibraphone', 'Viola'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Vibraphone'),
#  ('Bass', 'Bass'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'BbClarinet'),
#  ('Xylophone', 'Vibraphone'),
#  ('Vibraphone', 'Bass'),
#  ('Marimba', 'Marimba'),
#  ('Vibraphone', 'Viola'),
#  ('Vibraphone', 'Bass'),
#  ('Marimba', 'Oboe'),
#  ('Bass', 'Xylophone'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Trumpet'),
#  ('Bass', 'Violin'),
#  ('Marimba', 'Violin'),
#  ('Cello', 'Violin'),
#  ('Viola', 'Viola'),
#  ('Marimba', 'Marimba'),
#  ('Bass', 'Vibraphone'),
#  ('Bass', 'Bass'),
#  ('Marimba', 'BbClarinet'),
#  ('Marimba', 'BassFlute'),
#  ('Marimba', 'AltoSax'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'BbClarinet'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Marimba'),
#  ('Xylophone', 'Flute'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Violin'),
#  ('Bass', 'Marimba'),
#  ('Marimba', 'Oboe'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Violin'),
#  ('Bass', 'Marimba'),
#  ('Cello', 'Marimba'),
#  ('Bass', 'Violin'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'bells'),
#  ('Xylophone', 'Marimba'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Viola'),
#  ('Cello', 'Bass'),
#  ('Marimba', 'Tuba'),
#  ('Marimba', 'Marimba'),
#  ('Bass', 'AltoSax'),
#  ('Bass', 'Cello'),
#  ('Xylophone', 'Vibraphone'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Horn'),
#  ('Bass', 'EbClarinet'),
#  ('Marimba', 'Crotale'),
#  ('Xylophone', 'Trumpet'),
#  ('Xylophone', 'Flute'),
#  ('Vibraphone', 'Marimba'),
#  ('Viola', 'Violin'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Viola'),
#  ('Vibraphone', 'Violin'),
#  ('Marimba', 'Cello'),
#  ('Cello', 'Vibraphone'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Marimba'),
#  ('Vibraphone', 'Bassoon'),
#  ('Bass', 'BbClarinet'),
#  ('Xylophone', 'Vibraphone'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Violin'),
#  ('Vibraphone', 'Xylophone'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Cello'),
#  ('Cello', 'EbClarinet'),
#  ('Bass', 'Cello'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Oboe'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Violin'),
#  ('Xylophone', 'Bassoon'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Marimba'),
#  ('Vibraphone', 'Bass'),
#  ('Tuba', 'Bassoon'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Marimba'),
#  ('Vibraphone', 'Vibraphone'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'bells'),
#  ('AltoSax', 'Bass'),
#  ('Bass', 'Violin'),
#  ('Bass', 'Vibraphone'),
#  ('Vibraphone', 'BassFlute'),
#  ('Bass', 'Vibraphone'),
#  ('Bass', 'Horn'),
#  ('Marimba', 'SopSax'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'TenorTrombone'),
#  ('Marimba', 'Violin'),
#  ('Xylophone', 'Marimba'),
#  ('Marimba', 'Violin'),
#  ('Xylophone', 'Xylophone'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Bassoon'),
#  ('Vibraphone', 'BbClarinet'),
#  ('Marimba', 'TenorTrombone'),
#  ('Vibraphone', 'Cello'),
#  ('Marimba', 'Tuba'),
#  ('Bass', 'Bass'),
#  ('Xylophone', 'Marimba'),
#  ('Marimba', 'Viola'),
#  ('Vibraphone', 'Viola'),
#  ('Xylophone', 'Marimba'),
#  ('Vibraphone', 'Marimba'),
#  ('Marimba', 'SopSax'),
#  ('Marimba', 'Bass'),
#  ('Bass', 'Violin'),
#  ('Marimba', 'Oboe'),
#  ('Bass', 'Bassoon'),
#  ('Marimba', 'Marimba'),
#  ('Xylophone', 'Bass'),
#  ('Vibraphone', 'Trumpet'),
#  ('Marimba', 'Viola'),
#  ('Xylophone', 'Cello'),
#  ('Marimba', 'Bass'),
#  ('Xylophone', 'Flute'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Bass'),
#  ('Vibraphone', 'Cello'),
#  ('Marimba', 'Trumpet'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'Bass'),
#  ('Xylophone', 'Trumpet'),
#  ('Marimba', 'Viola'),
#  ('Bass', 'Violin'),
#  ('Xylophone', 'Violin'),
#  ('Xylophone', 'Vibraphone'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'BassClarinet'),
#  ('Xylophone', 'Horn'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Violin'),
#  ('Xylophone', 'Viola'),
#  ('Marimba', 'Trumpet'),
#  ('Vibraphone', 'Xylophone'),
#  ('Marimba', 'BassClarinet'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Bassoon'),
#  ('Tuba', 'BassClarinet'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'EbClarinet'),
#  ('Marimba', 'Vibraphone'),
#  ('Xylophone', 'Trumpet'),
#  ('Vibraphone', 'Bass'),
#  ('Marimba', 'SopSax'),
#  ('Xylophone', 'Vibraphone'),
#  ('Xylophone', 'Bass'),
#  ('Marimba', 'BbClarinet'),
#  ('Bass', 'Marimba'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'TenorTrombone'),
#  ('Marimba', 'Flute'),
#  ('Vibraphone', 'Cello'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'EbClarinet'),
#  ('Vibraphone', 'Horn'),
#  ('Marimba', 'Marimba'),
#  ('Cello', 'SopSax'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'Marimba'),
#  ('Bass', 'Xylophone'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Vibraphone'),
#  ('Xylophone', 'bells'),
#  ('Marimba', 'SopSax'),
#  ('Marimba', 'BassFlute'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'EbClarinet'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Trumpet'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Marimba'),
#  ('Bass', 'Marimba'),
#  ('Xylophone', 'Vibraphone'),
#  ('Marimba', 'AltoSax'),
#  ('Marimba', 'Flute'),
#  ('Vibraphone', 'Violin'),
#  ('Marimba', 'Viola'),
#  ('Bass', 'Xylophone'),
#  ('Tuba', 'Violin'),
#  ('Vibraphone', 'Marimba'),
#  ('Marimba', 'Flute'),
#  ('Xylophone', 'Flute'),
#  ('Marimba', 'Crotale'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'Xylophone'),
#  ('Vibraphone', 'Viola'),
#  ('Vibraphone', 'TenorTrombone'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'AltoFlute'),
#  ('Cello', 'Flute'),
#  ('Vibraphone', 'Marimba'),
#  ('Bass', 'Flute'),
#  ('Marimba', 'Tuba'),
#  ('Bass', 'Cello'),
#  ('Vibraphone', 'BassTrombone'),
#  ('Bass', 'Flute'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'BassClarinet'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Trumpet'),
#  ('Viola', 'Marimba'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'Crotale'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'SopSax'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'BbClarinet'),
#  ('Marimba', 'Flute'),
#  ('Viola', 'BbClarinet'),
#  ('Marimba', 'BassClarinet'),
#  ('Xylophone', 'Marimba'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Bassoon'),
#  ('Marimba', 'Cello'),
#  ('Viola', 'Bassoon'),
#  ('Marimba', 'BbClarinet'),
#  ('Vibraphone', 'Vibraphone'),
#  ('Marimba', 'AltoFlute'),
#  ('Bass', 'SopSax'),
#  ('Vibraphone', 'Bass'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Violin'),
#  ('Bass', 'Bass'),
#  ('Marimba', 'BassClarinet'),
#  ('Marimba', 'Bassoon'),
#  ('Marimba', 'Flute'),
#  ('Marimba', 'Xylophone'),
#  ('Marimba', 'BbClarinet'),
#  ('Bass', 'Trumpet'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Flute'),
#  ('Bass', 'Bass'),
#  ('Xylophone', 'Horn'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'TenorTrombone'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'BassTrombone'),
#  ('Tuba', 'Flute'),
#  ('Vibraphone', 'Marimba'),
#  ('Marimba', 'Flute'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'Viola'),
#  ('Tuba', 'EbClarinet'),
#  ('Bass', 'BassFlute'),
#  ('Marimba', 'Viola'),
#  ('Xylophone', 'BbClarinet'),
#  ('Marimba', 'Flute'),
#  ('Marimba', 'Tuba'),
#  ('Marimba', 'AltoSax'),
#  ('Marimba', 'Marimba'),
#  ('Xylophone', 'Vibraphone'),
#  ('Marimba', 'AltoSax'),
#  ('Viola', 'bells'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'SopSax'),
#  ('Viola', 'Viola'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Vibraphone'),
#  ('Bass', 'Xylophone'),
#  ('Marimba', 'Viola'),
#  ('Xylophone', 'Bass'),
#  ('Marimba', 'Xylophone'),
#  ('AltoSax', 'AltoFlute'),
#  ('Tuba', 'Bass'),
#  ('Viola', 'Viola'),
#  ('Vibraphone', 'Cello'),
#  ('Marimba', 'Marimba'),
#  ('Bass', 'Bass'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Horn'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'AltoFlute'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'Tuba'),
#  ('Bass', 'Tuba'),
#  ('Vibraphone', 'Xylophone'),
#  ('Marimba', 'Flute'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Violin'),
#  ('Bass', 'AltoFlute'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Bass'),
#  ('Vibraphone', 'SopSax'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'Flute'),
#  ('Marimba', 'AltoFlute'),
#  ('Marimba', 'Cello'),
#  ('Xylophone', 'AltoSax'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'Oboe'),
#  ('Bass', 'Trumpet'),
#  ('Marimba', 'BassTrombone'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Trumpet'),
#  ('Bass', 'Vibraphone'),
#  ('Viola', 'Cello'),
#  ('Marimba', 'BbClarinet'),
#  ('Vibraphone', 'AltoFlute'),
#  ('Xylophone', 'Xylophone'),
#  ('Xylophone', 'Bass'),
#  ('Marimba', 'Flute'),
#  ('Marimba', 'Vibraphone'),
#  ('Cello', 'Vibraphone'),
#  ('Marimba', 'BassFlute'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Bassoon'),
#  ('Marimba', 'BassFlute'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'AltoFlute'),
#  ('Xylophone', 'Trumpet'),
#  ('Vibraphone', 'Trumpet'),
#  ('Cello', 'Violin'),
#  ('Xylophone', 'Xylophone'),
#  ('Xylophone', 'bells'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Vibraphone'),
#  ('Xylophone', 'Viola'),
#  ('Marimba', 'Marimba'),
#  ('Xylophone', 'Bassoon'),
#  ('Marimba', 'Violin'),
#  ('Vibraphone', 'Xylophone'),
#  ('Bass', 'Vibraphone'),
#  ('Marimba', 'AltoSax'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Marimba'),
#  ('Vibraphone', 'Bass'),
#  ('Marimba', 'Vibraphone'),
#  ('Vibraphone', 'Vibraphone'),
#  ('Vibraphone', 'bells'),
#  ('Vibraphone', 'Tuba'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'BassFlute'),
#  ('Marimba', 'EbClarinet'),
#  ('Marimba', 'Vibraphone'),
#  ('Bass', 'AltoFlute'),
#  ('Marimba', 'Violin'),
#  ('Bass', 'Cello'),
#  ('Marimba', 'Bass'),
#  ('Vibraphone', 'Marimba'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Violin'),
#  ('Marimba', 'BassTrombone'),
#  ('Marimba', 'Marimba'),
#  ('Bass', 'BassTrombone'),
#  ('Xylophone', 'Violin'),
#  ('Cello', 'Viola'),
#  ('Xylophone', 'Marimba'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'EbClarinet'),
#  ('Tuba', 'Bassoon'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'TenorTrombone'),
#  ('Vibraphone', 'Marimba'),
#  ('Marimba', 'Bass'),
#  ('Xylophone', 'Viola'),
#  ('Xylophone', 'Marimba'),
#  ('Marimba', 'AltoFlute'),
#  ('Xylophone', 'BbClarinet'),
#  ('Marimba', 'Cello'),
#  ('Viola', 'Bass'),
#  ('Marimba', 'Bass'),
#  ('Marimba', 'Oboe'),
#  ('Xylophone', 'Xylophone'),
#  ('Marimba', 'BassClarinet'),
#  ('Marimba', 'Horn'),
#  ('Cello', 'EbClarinet'),
#  ('Marimba', 'EbClarinet'),
#  ('Marimba', 'Viola'),
#  ('Xylophone', 'Cello'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'Horn'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'BassClarinet'),
#  ('Marimba', 'Violin'),
#  ('Bass', 'Xylophone'),
#  ('AltoSax', 'Bass'),
#  ('Marimba', 'BassFlute'),
#  ('Xylophone', 'Cello'),
#  ('Marimba', 'Marimba'),
#  ('Xylophone', 'BbClarinet'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'AltoSax'),
#  ('Xylophone', 'Viola'),
#  ('Marimba', 'BassFlute'),
#  ('Marimba', 'Vibraphone'),
#  ('Marimba', 'Cello'),
#  ('Marimba', 'Viola'),
#  ('Vibraphone', 'Violin'),
#  ('Marimba', 'Marimba'),
#  ('Marimba', 'BassTrombone'),
#  ('Marimba', 'Viola'),
#  ('Marimba', 'bells'),
#  ('Marimba', 'SopSax'),
#  ('Marimba', 'Bassoon'),
#  ('Marimba', 'EbClarinet')]
