# %%
def note_name_to_midi_number(note_name): # Note names must be capital letters
                                         # Valid inputs are C0 through G9
    note_letter = note_name[:-1]
    octave_number = int(note_name[-1])
    note_number = {'C' : 0,
                   'C#' : 1, 'Db': 1,
                   'D' : 2,
                   'D#' : 3, 'Eb' : 3,
                   'E' : 4,
                   'F' : 5,
                   'F#' : 6, 'Gb': 6,
                   'G' : 7,
                   'G#': 8, 'Ab': 8,
                   'A' : 9,
                   'A#' : 10, 'Bb': 10,
                   'B' : 11}
    return 12*(1+octave_number) + note_number[note_letter]

def note_midi_number_to_name(note_midi_number): # MIDI numbers must be integers
                                                # Valid inputs are 12 through 127
    octave_number = (note_midi_number // 12) - 1
    note_number = note_midi_number % 12
    note_letter = {0 : 'C',
                   1: 'Db',
                   2: 'D',
                   3: 'Eb',
                   4 : 'E',
                   5 : 'F',
                   6: 'Gb',
                   7: 'G',
                   8: 'Ab',
                   9: 'A',
                   10: 'Bb',
                   11: 'B'}
    return note_letter[note_number] + str(octave_number)

# %%
# from os import listdir, getcwd, rename, remove
# from os.path import isfile, join

# path = join(getcwd(), 'Soundfont Creation', 'freepats-tools', 'samples')

# files = [f for f in listdir(path) if isfile(join(path, f)) and f[0] != '.']

# samples = []
# for f in files:
#     #print(f.split('.'))
#     sample = {'instrument' : f.split('.')[0],
#               'note' : f.split('.')[-3],
#               'midi_number' : note_name_to_midi_number(f.split('.')[-3]),
#               'expression' : '_'.join(f.split('.')[1:-3]) if len(f.split('.')) > 3 else '',
#               'filename' : f,
#               'extension' : f.split('.')[-1]}
#     samples.append(sample)
# for s in sorted(samples, key=lambda x: x['midi_number']):
#     print(s)
#     print('')

# %%
import soundfile as sf
from librosa.onset import onset_detect
from librosa.core import to_mono

from os import listdir, getcwd, rename, remove, makedirs
from os.path import isfile, join, basename, exists

def preprocess_sample_onsets(sample_info):
    # extract sample information
    input_filename = sample_info['filename']
    instrument = sample_info['instrument']
    expression = sample_info['expression']
    midi_number = sample_info['midi_number']
    
    # read sample from storage
    input_data, samplerate = sf.read(input_filename)
    
    # detect onset with librosa, then clip input data to start of onset with backtracking
    onsets = onset_detect(y=to_mono(input_data.T), sr=samplerate, hop_length=1, backtrack=True, units='samples')
    if len(onsets) > 0:
        onset = onsets[0]
    else:
        onset = 0
    output_data = input_data[onset:,:]
    
    # create directory for preprocessed samples if does not already exist
    if not exists('preprocessed_samples'):
        makedirs('preprocessed_samples')
    
    # write preprocessed sample as 24-bit PCM wave file
    output_filename = join(getcwd(), 'preprocessed_samples', f"{instrument}_{expression}_{midi_number}.wav")
    print(f"Writing {output_filename} with offset {onset}")
    sf.write(output_filename, output_data, samplerate, subtype='PCM_24')
    
    # return MySQL query and values (in this case, nothing)
    return None, None

# %%
import config

import mysql
import mysql.connector
from mysql.connector import errorcode

import logging
import boto3
from botocore.exceptions import ClientError

def connect(db_name=None):
    if db_name:
        cnx = mysql.connector.connect(
            host = config.rds_host,
            user = config.rds_user,
            passwd = config.rds_password,
            database = db_name)
    else:
        cnx = mysql.connector.connect(
            host = config.rds_host,
            user = config.rds_user,
            passwd = config.rds_password)
    cursor = cnx.cursor()
    return cursor, cnx

def download_file(object_name, bucket='instrument-samples-1337', file_name=None):
    """Download a file from an S3 bucket

    :param object_name: S3 object to download
    :param bucket: Bucket to download from
    :param file_name: file name to download to. If not specified then object_name is used
    :return: True if file was uploaded, else False
    """

    # If S3 object_name was not specified, use file_name
    if file_name is None:
        file_name = object_name

    # Upload the file
    s3_client = boto3.client('s3',
                             aws_access_key_id=config.aws_access_key_id,
                             aws_secret_access_key=config.aws_secret_access_key)
    try:
        response = s3_client.download_file(bucket, object_name, file_name)
    except ClientError as e:
        logging.error(e)
        return False
    return True

# %%
from os import listdir, getcwd, rename, remove, makedirs
from os.path import isfile, join, basename, exists
import pandas as pd

def process_sample(sample_id, processing_function):
    cur, cnx = connect('sound_shift')
    cur.execute(f"""SELECT * FROM sound_shift.samples
                    WHERE sample_id = {sample_id}""")
    df = pd.DataFrame(cur.fetchall())
    df.columns = [i[0] for i in cur.description]
    sample_metadata = df.iloc[0]
    print('Attemping to download the following sample:')
    print(sample_metadata)
    sample_info = {'id' : int(sample_metadata['sample_id']),
                   'instrument' : sample_metadata['instrument_name'],
                   'note' : sample_metadata['note'],
                   'midi_number' : note_name_to_midi_number(sample_metadata['note']),
                   'expression' : '_'.join(sample_metadata['expression'].split(' ')),
                   'filename' : join(getcwd(), 'tempfiles', sample_metadata['file_name']),
                   'object_name' : f"{sample_metadata['sample_id']}.{sample_metadata['file_extension']}",
                   'extension' : sample_metadata['file_extension']}
    sample_id = sample_info['id']
    sample_file_ext = sample_info['extension']
    object_name = sample_info['object_name']
    file_name = sample_info['filename']
    print(object_name)
    if not exists('tempfiles'):
        makedirs('tempfiles')
    if download_file(object_name, file_name=file_name):
        print(f'Processing sample with {processing_function} ...')
        query, values = processing_function(sample_info)
        if query:
            cur.executemany(query, values)
        remove(file_name)
        cnx.commit()
        cnx.close()
        print('Done!')
        print('')
    else:
        print('Download failed.')
        print('')
        cnx.close()

# %%
import gc

for i in range(2219,2230):
    process_sample(i, preprocess_sample_onsets)
    gc.collect()

# %% [markdown]
# #### Alternative multithreaded preprocessing

# %%
# Alternative Multithreaded code to perform preprocessing of samples.
# This is naive multithreaded code, so use with caution. Try using
# relatively small batch sizes so that you can catch failures early.

import _thread as thread
import gc

def batch_preprocess_by_sample_index(index_list):
    for i in index_list:
        process_sample(i, preprocess_sample_onsets)
        gc.collect()
    print(f'COMPLETED PREPROCESSING SAMPLES IN {index_list}')

    
# Example of processing four batches in parallel

thread.start_new_thread(batch_preprocess_by_sample_index, (list(range(2047,2100)),) )
thread.start_new_thread(batch_preprocess_by_sample_index, (list(range(2289,2300)),) )
# Out:
# 123145544892416
# Attemping to download the following sample:
# sample_id                                         2047
# instrument_name                             Vibraphone
# note                                                B5
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.B5.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2047.aif
# Attemping to download the following sample:
# sample_id                                  2289
# instrument_name                           bells
# note                                         C6
# expression                             brass ff
# source                                 Iowa2012
# file_name          bells.brass.ff.C6.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2289.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_84.wav with offset 9387
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2290
# instrument_name                           bells
# note                                         B7
# expression                             brass ff
# source                                 Iowa2012
# file_name          bells.brass.ff.B7.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2290.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_107.wav with offset 5349
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2291
# instrument_name                           bells
# note                                         D5
# expression                             brass ff
# source                                 Iowa2012
# file_name          bells.brass.ff.D5.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2291.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_83.wav with offset 2184
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2048
# instrument_name                              Vibraphone
# note                                                Ab4
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Ab4.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2048.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_74.wav with offset 26596
# Done!
#
# Attemping to download the following sample:
# sample_id                                   2292
# instrument_name                            bells
# note                                         Ab6
# expression                              brass ff
# source                                  Iowa2012
# file_name          bells.brass.ff.Ab6.stereo.aif
# file_extension                               aif
# Name: 0, dtype: object
# 2292.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_92.wav with offset 4656
# Done!
#
# Attemping to download the following sample:
# sample_id                                   2293
# instrument_name                            bells
# note                                         Db5
# expression                              brass ff
# source                                  Iowa2012
# file_name          bells.brass.ff.Db5.stereo.aif
# file_extension                               aif
# Name: 0, dtype: object
# 2293.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_68.wav with offset 2026
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2049
# instrument_name                             Vibraphone
# note                                                C4
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.C4.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2049.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_73.wav with offset 20400
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2294
# instrument_name                           bells
# note                                         E7
# expression                             brass ff
# source                                 Iowa2012
# file_name          bells.brass.ff.E7.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2294.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_100.wav with offset 3378
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2295
# instrument_name                           bells
# note                                         C5
# expression                             brass ff
# source                                 Iowa2012
# file_name          bells.brass.ff.C5.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2295.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_60.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2050
# instrument_name                             Vibraphone
# note                                                E6
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.E6.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2050.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_72.wav with offset 3203
# Done!
#
# Attemping to download the following sample:
# sample_id                                   2296
# instrument_name                            bells
# note                                         Db6
# expression                              brass ff
# source                                  Iowa2012
# file_name          bells.brass.ff.Db6.stereo.aif
# file_extension                               aif
# Name: 0, dtype: object
# 2296.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_88.wav with offset 1461
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2051
# instrument_name                             Vibraphone
# note                                                C3
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.C3.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2051.aif
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_85.wav with offset 2725
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2297
# instrument_name                           bells
# note                                         C8
# expression                             brass ff
# source                                 Iowa2012
# file_name          bells.brass.ff.C8.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2297.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_108.wav with offset 5574
# Done!
#
# Attemping to download the following sample:
# sample_id                                   2298
# instrument_name                            bells
# note                                         Ab5
# expression                              brass ff
# source                                  Iowa2012
# file_name          bells.brass.ff.Ab5.stereo.aif
# file_extension                               aif
# Name: 0, dtype: object
# 2298.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_80.wav with offset 3740
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2299
# instrument_name                           bells
# note                                         D6
# expression                             brass ff
# source                                 Iowa2012
# file_name          bells.brass.ff.D6.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2299.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_48.wav with offset 6309
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2052
# instrument_name                             Vibraphone
# note                                                F6
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.F6.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2052.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_brass_ff_86.wav with offset 7558
# Done!
#
# COMPLETED PREPROCESSING SAMPLES IN [2289, 2290, 2291, 2292, 2293, 2294, 2295, 2296, 2297, 2298, 2299]
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_89.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2053
# instrument_name                              Vibraphone
# note                                                Ab3
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Ab3.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2053.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_56.wav with offset 7801
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2054
# instrument_name                             Vibraphone
# note                                                A5
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.A5.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2054.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_81.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2055
# instrument_name                              Vibraphone
# note                                                Bb5
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Bb5.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2055.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_82.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2056
# instrument_name                              Vibraphone
# note                                                Eb5
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Eb5.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2056.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_75.wav with offset 2660
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2057
# instrument_name                             Vibraphone
# note                                                D5
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.D5.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2057.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_74.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2058
# instrument_name                              Vibraphone
# note                                                Gb3
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Gb3.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2058.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_54.wav with offset 7043
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2059
# instrument_name                              Vibraphone
# note                                                Db5
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Db5.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2059.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_73.wav with offset 1667
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2060
# instrument_name                             Vibraphone
# note                                                C6
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.C6.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2060.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_84.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2061
# instrument_name                             Vibraphone
# note                                                F3
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.F3.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2061.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_53.wav with offset 8621
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2062
# instrument_name                             Vibraphone
# note                                                E4
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.E4.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2062.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_64.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2063
# instrument_name                                  Vibraphone
# note                                                     B5
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.B5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2063.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_83.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2064
# instrument_name                                   Vibraphone
# note                                                     Db5
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Db5.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2064.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_73.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2065
# instrument_name                                  Vibraphone
# note                                                     C4
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.C4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2065.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_60.wav with offset 2199
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2066
# instrument_name                                  Vibraphone
# note                                                     E6
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.E6.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2066.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_88.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2067
# instrument_name                                   Vibraphone
# note                                                     Gb3
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Gb3.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2067.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_54.wav with offset 2161
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2068
# instrument_name                                   Vibraphone
# note                                                     Bb5
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Bb5.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2068.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_82.wav with offset 1140
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2069
# instrument_name                                   Vibraphone
# note                                                     Eb5
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Eb5.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2069.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_75.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2070
# instrument_name                                  Vibraphone
# note                                                     E3
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.E3.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2070.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_52.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2071
# instrument_name                                  Vibraphone
# note                                                     F4
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.F4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2071.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_65.wav with offset 3204
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2072
# instrument_name                                  Vibraphone
# note                                                     G5
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.G5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2072.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_79.wav with offset 1106
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2073
# instrument_name                                   Vibraphone
# note                                                     Ab3
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Ab3.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2073.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_56.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2074
# instrument_name                                   Vibraphone
# note                                                     Ab4
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Ab4.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2074.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_68.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2075
# instrument_name                                  Vibraphone
# note                                                     D5
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.D5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2075.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_74.wav with offset 2143
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2076
# instrument_name                                  Vibraphone
# note                                                     C6
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.C6.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2076.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_84.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2077
# instrument_name                                  Vibraphone
# note                                                     E4
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.E4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2077.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_64.wav with offset 3066
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2078
# instrument_name                                  Vibraphone
# note                                                     F3
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.F3.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2078.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_53.wav with offset 1125
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2079
# instrument_name                                   Vibraphone
# note                                                     Gb4
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Gb4.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2079.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_66.wav with offset 2233
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2080
# instrument_name                                  Vibraphone
# note                                                     C3
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.C3.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2080.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_48.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2081
# instrument_name                                  Vibraphone
# note                                                     F6
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.F6.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2081.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_89.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2082
# instrument_name                                  Vibraphone
# note                                                     A5
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.A5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2082.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_81.wav with offset 1098
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2083
# instrument_name                                   Vibraphone
# note                                                     Bb4
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Bb4.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2083.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_70.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2084
# instrument_name                                   Vibraphone
# note                                                     Eb4
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Eb4.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2084.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_63.wav with offset 3095
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2085
# instrument_name                                  Vibraphone
# note                                                     F5
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.F5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2085.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_77.wav with offset 2538
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2086
# instrument_name                                  Vibraphone
# note                                                     G4
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.G4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2086.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_67.wav with offset 3032
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2087
# instrument_name                                  Vibraphone
# note                                                     D3
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.D3.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2087.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_50.wav with offset 2967
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2088
# instrument_name                                  Vibraphone
# note                                                     D6
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.D6.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2088.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_86.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2089
# instrument_name                                  Vibraphone
# note                                                     B4
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.B4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2089.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_71.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2090
# instrument_name                                  Vibraphone
# note                                                     A3
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.A3.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2090.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_57.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2091
# instrument_name                                   Vibraphone
# note                                                     Db4
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Db4.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2091.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_61.wav with offset 2258
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2092
# instrument_name                                  Vibraphone
# note                                                     C5
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.C5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2092.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_72.wav with offset 2431
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2093
# instrument_name                                   Vibraphone
# note                                                     Gb5
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Gb5.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2093.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_78.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2094
# instrument_name                                   Vibraphone
# note                                                     Eb6
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Eb6.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2094.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_87.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2095
# instrument_name                                   Vibraphone
# note                                                     Db3
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Db3.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2095.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_49.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2096
# instrument_name                                  Vibraphone
# note                                                     B3
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.B3.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2096.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_59.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2097
# instrument_name                                  Vibraphone
# note                                                     A4
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.A4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2097.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_69.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2098
# instrument_name                                   Vibraphone
# note                                                     Db6
# expression                                   shortsustain ff
# source                                              Iowa2012
# file_name          Vibraphone.shortsustain.ff.Db6.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2098.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_85.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2099
# instrument_name                                  Vibraphone
# note                                                     G3
# expression                                  shortsustain ff
# source                                             Iowa2012
# file_name          Vibraphone.shortsustain.ff.G3.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2099.aif
# Processing sample with <function preprocess_sample_onsets at 0x109911158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_shortsustain_ff_55.wav with offset 1506
# Done!
#
# COMPLETED PREPROCESSING SAMPLES IN [2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099]

# %%
cur, cnx = connect('sound_shift')
cur.execute(f"""SELECT * FROM sound_shift.samples""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
cnx.close()

# %%
def g(row):
    result = row['instrument_name']
    result += '_' + '_'.join(row['expression'].split())
    note_number = note_name_to_midi_number(row['note'])
    result += '_' + str(note_number) + '.wav'
    return result

# %%
df['filename'] = df.apply(g, axis=1)

# %%
df
# Out:
#       sample_id instrument_name note expression    source  \
# 0             1           Flute  Gb6     vib ff  Iowa2012
# 1             2           Flute  Bb5     vib ff  Iowa2012
# 2             3           Flute   G4     vib ff  Iowa2012
# 3             4           Flute  Eb5     vib ff  Iowa2012
# 4             5           Flute   A6     vib ff  Iowa2012
# ...         ...             ...  ...        ...       ...
# 2228       2333         Crotale  Gb6         ff  Iowa2012
# 2229       2334         Crotale   A7         ff  Iowa2012
# 2230       2335         Crotale   E6         ff  Iowa2012
# 2231       2336         Crotale  Ab6         ff  Iowa2012
# 2232       2337         Crotale   D7         ff  Iowa2012
#
#                         file_name file_extension             filename
# 0     Flute.vib.ff.Gb6.stereo.aif            aif  Flute_vib_ff_90.wav
# 1     Flute.vib.ff.Bb5.stereo.aif            aif  Flute_vib_ff_82.wav
# 2      Flute.vib.ff.G4.stereo.aif            aif  Flute_vib_ff_67.wav
# 3     Flute.vib.ff.Eb5.stereo.aif            aif  Flute_vib_ff_75.wav
# 4      Flute.vib.ff.A6.stereo.aif            aif  Flute_vib_ff_93.wav
# ...                           ...            ...                  ...
# 2228    Crotale.ff.Gb6.stereo.aif            aif    Crotale_ff_90.wav
# 2229     Crotale.ff.A7.stereo.aif            aif   Crotale_ff_105.wav
# 2230     Crotale.ff.E6.stereo.aif            aif    Crotale_ff_88.wav
# 2231    Crotale.ff.Ab6.stereo.aif            aif    Crotale_ff_92.wav
# 2232     Crotale.ff.D7.stereo.aif            aif    Crotale_ff_98.wav
#
# [2233 rows x 8 columns]

# %%
from os import listdir, getcwd, rename, remove
from os.path import isfile, join

path = join(getcwd(), 'preprocessed_samples')

files = [f for f in listdir(path) if isfile(join(path, f)) and f[0] != '.']

# %%
df['processed'] = df.apply(lambda x: (x['filename'] in files), axis=1)

# %%
files2 = list(df['filename'])
len(set(files2))
# Out:
# 2233

# %%
len(files2)
# Out:
# 2233

# %%
[(files2[i],files2[j]) for i in range(2275) for j in range(2275) if files2[i] == files2[j] and i != j]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-094ed4ec383c> in <module>
# ----> 1 [(files2[i],files2[j]) for i in range(2275) for j in range(2275) if files2[i] == files2[j] and i != j]
#
# <ipython-input-80-094ed4ec383c> in <listcomp>(.0)
# ----> 1 [(files2[i],files2[j]) for i in range(2275) for j in range(2275) if files2[i] == files2[j] and i != j]
#
# IndexError: list index out of range

# %%
len(files)
# Out:
# 2233

# %%
len(df)
# Out:
# 2233

# %%
df.iloc[810:830,:]
# Out:
#      sample_id instrument_name note    expression    source  \
# 810        811          Violin   B5  pizz ff sulA  Iowa2012
# 811        812          Violin  Ab5  pizz ff sulA  Iowa2012
# 812        813          Violin   E6  pizz ff sulA  Iowa2012
# 813        814          Violin   D6  pizz ff sulA  Iowa2012
# 814        815          Violin  Db6  pizz ff sulA  Iowa2012
# 815        816          Violin   F6  pizz ff sulA  Iowa2012
# 816        817          Violin   A5  pizz ff sulA  Iowa2012
# 817        818          Violin  Bb4  pizz ff sulA  Iowa2012
# 818        819          Violin   D5  pizz ff sulA  Iowa2012
# 819        820          Violin   C6  pizz ff sulA  Iowa2012
# 820        821          Violin   D6  pizz ff sulA  Iowa2012
# 821        822          Violin   B4  pizz ff sulA  Iowa2012
# 822        823          Violin   C5  pizz ff sulA  Iowa2012
# 823        824          Violin   F5  pizz ff sulA  Iowa2012
# 824        825          Violin  Db5  pizz ff sulA  Iowa2012
# 825        826          Violin   E5  pizz ff sulA  Iowa2012
# 826        827          Violin   A4  pizz ff sulA  Iowa2012
# 827        828          Violin  Eb5  pizz ff sulA  Iowa2012
# 828        829          Violin  Bb5  pizz ff sulA  Iowa2012
# 829        830          Violin   E6  arco ff sulE  Iowa2012
#
#                               file_name file_extension  \
# 810   Violin.pizz.ff.sulA.B5.stereo.aif            aif
# 811  Violin.pizz.ff.sulA.Ab5.stereo.aif            aif
# 812   Violin.pizz.ff.sulA.E6.stereo.aif            aif
# 813   Violin.pizz.ff.sulA.D6.stereo.aif            aif
# 814  Violin.pizz.ff.sulA.Db6.stereo.aif            aif
# 815   Violin.pizz.ff.sulA.F6.stereo.aif            aif
# 816   Violin.pizz.ff.sulA.A5.stereo.aif            aif
# 817  Violin.pizz.ff.sulA.Bb4.stereo.aif            aif
# 818   Violin.pizz.ff.sulA.D5.stereo.aif            aif
# 819   Violin.pizz.ff.sulA.C6.stereo.aif            aif
# 820   Violin.pizz.ff.sulA.D6.stereo.aif            aif
# 821   Violin.pizz.ff.sulA.B4.stereo.aif            aif
# 822   Violin.pizz.ff.sulA.C5.stereo.aif            aif
# 823   Violin.pizz.ff.sulA.F5.stereo.aif            aif
# 824  Violin.pizz.ff.sulA.Db5.stereo.aif            aif
# 825   Violin.pizz.ff.sulA.E5.stereo.aif            aif
# 826   Violin.pizz.ff.sulA.A4.stereo.aif            aif
# 827  Violin.pizz.ff.sulA.Eb5.stereo.aif            aif
# 828  Violin.pizz.ff.sulA.Bb5.stereo.aif            aif
# 829   Violin.arco.ff.sulE.E6.stereo.aif            aif
#
#                        filename  processed
# 810  Violin_pizz_ff_sulA_83.wav       True
# 811  Violin_pizz_ff_sulA_80.wav       True
# 812  Violin_pizz_ff_sulA_88.wav       True
# 813  Violin_pizz_ff_sulA_86.wav       True
# 814  Violin_pizz_ff_sulA_85.wav       True
# 815  Violin_pizz_ff_sulA_89.wav       True
# 816  Violin_pizz_ff_sulA_81.wav       True
# 817  Violin_pizz_ff_sulA_70.wav       True
# 818  Violin_pizz_ff_sulA_74.wav       True
# 819  Violin_pizz_ff_sulA_84.wav       True
# 820  Violin_pizz_ff_sulA_86.wav       True
# 821  Violin_pizz_ff_sulA_71.wav       True
# 822  Violin_pizz_ff_sulA_72.wav       True
# 823  Violin_pizz_ff_sulA_77.wav       True
# 824  Violin_pizz_ff_sulA_73.wav       True
# 825  Violin_pizz_ff_sulA_76.wav       True
# 826  Violin_pizz_ff_sulA_69.wav       True
# 827  Violin_pizz_ff_sulA_75.wav       True
# 828  Violin_pizz_ff_sulA_82.wav       True
# 829  Violin_arco_ff_sulE_88.wav       True
