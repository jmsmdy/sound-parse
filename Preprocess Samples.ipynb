# %%
def note_name_to_midi_number(note_name): # Note names must be capital letters
                                         # Valid inputs are C0 through G9
    note_letter = note_name[:-1]
    octave_number = int(note_name[-1])
    note_number = {'C' : 0,
                   'C#' : 1, 'Db': 1,
                   'D' : 2,
                   'D#' : 3, 'Eb' : 3,
                   'E' : 4,
                   'F' : 5,
                   'F#' : 6, 'Gb': 6,
                   'G' : 7,
                   'G#': 8, 'Ab': 8,
                   'A' : 9,
                   'A#' : 10, 'Bb': 10,
                   'B' : 11}
    return 12*(1+octave_number) + note_number[note_letter]

def note_midi_number_to_name(note_midi_number): # MIDI numbers must be integers
                                                # Valid inputs are 12 through 127
    octave_number = (note_midi_number // 12) - 1
    note_number = note_midi_number % 12
    note_letter = {0 : 'C',
                   1: 'Db',
                   2: 'D',
                   3: 'Eb',
                   4 : 'E',
                   5 : 'F',
                   6: 'Gb',
                   7: 'G',
                   8: 'Ab',
                   9: 'A',
                   10: 'Bb',
                   11: 'B'}
    return note_letter[note_number] + str(octave_number)

# %%
# from os import listdir, getcwd, rename, remove
# from os.path import isfile, join

# path = join(getcwd(), 'Soundfont Creation', 'freepats-tools', 'samples')

# files = [f for f in listdir(path) if isfile(join(path, f)) and f[0] != '.']

# samples = []
# for f in files:
#     #print(f.split('.'))
#     sample = {'instrument' : f.split('.')[0],
#               'note' : f.split('.')[-3],
#               'midi_number' : note_name_to_midi_number(f.split('.')[-3]),
#               'expression' : '_'.join(f.split('.')[1:-3]) if len(f.split('.')) > 3 else '',
#               'filename' : f,
#               'extension' : f.split('.')[-1]}
#     samples.append(sample)
# for s in sorted(samples, key=lambda x: x['midi_number']):
#     print(s)
#     print('')

# %%
import soundfile as sf
from librosa.onset import onset_detect
from librosa.core import to_mono

from os import listdir, getcwd, rename, remove, makedirs
from os.path import isfile, join, basename, exists

def preprocess_sample_onsets(sample_info):
    # extract sample information
    input_filename = sample_info['filename']
    instrument = sample_info['instrument']
    expression = sample_info['expression']
    midi_number = sample_info['midi_number']
    
    # read sample from storage
    input_data, samplerate = sf.read(input_filename)
    
    # detect onset with librosa, then clip input data to start of onset with backtracking
    onsets = onset_detect(y=to_mono(input_data.T), sr=samplerate, hop_length=1, backtrack=True, units='samples')
    if len(onsets) > 0:
        onset = onsets[0]
    else:
        onset = 0
    output_data = input_data[onset:,:]
    
    # create directory for preprocessed samples if does not already exist
    if not exists('preprocessed_samples'):
        makedirs('preprocessed_samples')
    
    # write preprocessed sample as 24-bit PCM wave file
    output_filename = join(getcwd(), 'preprocessed_samples', f"{instrument}_{expression}_{midi_number}.wav")
    print(f"Writing {output_filename} with offset {onset}")
    sf.write(output_filename, output_data, samplerate, subtype='PCM_24')
    
    # return MySQL query and values (in this case, nothing)
    return None, None

# %%
import config

import mysql
import mysql.connector
from mysql.connector import errorcode

import logging
import boto3
from botocore.exceptions import ClientError

def connect(db_name=None):
    if db_name:
        cnx = mysql.connector.connect(
            host = config.rds_host,
            user = config.rds_user,
            passwd = config.rds_password,
            database = db_name)
    else:
        cnx = mysql.connector.connect(
            host = config.rds_host,
            user = config.rds_user,
            passwd = config.rds_password)
    cursor = cnx.cursor()
    return cursor, cnx

def download_file(object_name, bucket='instrument-samples-1337', file_name=None):
    """Download a file from an S3 bucket

    :param object_name: S3 object to download
    :param bucket: Bucket to download from
    :param file_name: file name to download to. If not specified then object_name is used
    :return: True if file was uploaded, else False
    """

    # If S3 object_name was not specified, use file_name
    if file_name is None:
        file_name = object_name

    # Upload the file
    s3_client = boto3.client('s3',
                             aws_access_key_id=config.aws_access_key_id,
                             aws_secret_access_key=config.aws_secret_access_key)
    try:
        response = s3_client.download_file(bucket, object_name, file_name)
    except ClientError as e:
        logging.error(e)
        return False
    return True

# %%
from os import listdir, getcwd, rename, remove, makedirs
from os.path import isfile, join, basename, exists
import pandas as pd

def process_sample(sample_id, processing_function):
    cur, cnx = connect('sound_shift')
    cur.execute(f"""SELECT * FROM sound_shift.samples
                    WHERE sample_id = {sample_id}""")
    df = pd.DataFrame(cur.fetchall())
    df.columns = [i[0] for i in cur.description]
    sample_metadata = df.iloc[0]
    print('Attemping to download the following sample:')
    print(sample_metadata)
    sample_info = {'id' : int(sample_metadata['sample_id']),
                   'instrument' : sample_metadata['instrument_name'],
                   'note' : sample_metadata['note'],
                   'midi_number' : note_name_to_midi_number(sample_metadata['note']),
                   'expression' : '_'.join(sample_metadata['expression'].split(' ')),
                   'filename' : join(getcwd(), 'tempfiles', sample_metadata['file_name']),
                   'object_name' : f"{sample_metadata['sample_id']}.{sample_metadata['file_extension']}",
                   'extension' : sample_metadata['file_extension']}
    sample_id = sample_info['id']
    sample_file_ext = sample_info['extension']
    object_name = sample_info['object_name']
    file_name = sample_info['filename']
    print(object_name)
    if not exists('tempfiles'):
        makedirs('tempfiles')
    if download_file(object_name, file_name=file_name):
        print(f'Processing sample with {processing_function} ...')
        query, values = processing_function(sample_info)
        if query:
            cur.executemany(query, values)
        remove(file_name)
        cnx.commit()
        cnx.close()
        print('Done!')
        print('')
    else:
        print('Download failed.')
        print('')
        cnx.close()

# %%
import gc

for i in range(2219,2230):
    process_sample(i, preprocess_sample_onsets)
    gc.collect()
# Out:
# Attemping to download the following sample:
# sample_id                                   2219
# instrument_name                       Vibraphone
# note                                         Db3
# expression                                   bow
# source                                  Iowa2012
# file_name          Vibraphone.bow.Db3.stereo.aif
# file_extension                               aif
# Name: 0, dtype: object
# 2219.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_49.wav with offset 8358
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2220
# instrument_name                      Vibraphone
# note                                         D4
# expression                                  bow
# source                                 Iowa2012
# file_name          Vibraphone.bow.D4.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2220.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_62.wav with offset 24535
# Done!
#
# Attemping to download the following sample:
# sample_id                                   2221
# instrument_name                       Vibraphone
# note                                         Db4
# expression                                   bow
# source                                  Iowa2012
# file_name          Vibraphone.bow.Db4.stereo.aif
# file_extension                               aif
# Name: 0, dtype: object
# 2221.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_61.wav with offset 6185
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2222
# instrument_name                      Vibraphone
# note                                         G4
# expression                                  bow
# source                                 Iowa2012
# file_name          Vibraphone.bow.G4.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2222.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_67.wav with offset 44838
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2223
# instrument_name                      Vibraphone
# note                                         D3
# expression                                  bow
# source                                 Iowa2012
# file_name          Vibraphone.bow.D3.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2223.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_50.wav with offset 7411
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2224
# instrument_name                      Vibraphone
# note                                         F5
# expression                                  bow
# source                                 Iowa2012
# file_name          Vibraphone.bow.F5.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2224.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_77.wav with offset 17954
# Done!
#
# Attemping to download the following sample:
# sample_id                                   2225
# instrument_name                       Vibraphone
# note                                         Eb4
# expression                                   bow
# source                                  Iowa2012
# file_name          Vibraphone.bow.Eb4.stereo.aif
# file_extension                               aif
# Name: 0, dtype: object
# 2225.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_63.wav with offset 36121
# Done!
#
# Attemping to download the following sample:
# sample_id                                   2226
# instrument_name                       Vibraphone
# note                                         Bb4
# expression                                   bow
# source                                  Iowa2012
# file_name          Vibraphone.bow.Bb4.stereo.aif
# file_extension                               aif
# Name: 0, dtype: object
# 2226.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_70.wav with offset 26678
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2227
# instrument_name                      Vibraphone
# note                                         C5
# expression                                  bow
# source                                 Iowa2012
# file_name          Vibraphone.bow.C5.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2227.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_72.wav with offset 3497
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2228
# instrument_name                      Vibraphone
# note                                         B4
# expression                                  bow
# source                                 Iowa2012
# file_name          Vibraphone.bow.B4.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2228.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_71.wav with offset 6955
# Done!
#
# Attemping to download the following sample:
# sample_id                                  2229
# instrument_name                      Vibraphone
# note                                         A3
# expression                                  bow
# source                                 Iowa2012
# file_name          Vibraphone.bow.A3.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2229.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_57.wav with offset 33677
# Done!

# %% [markdown]
# #### Alternative multithreaded preprocessing

# %%
# Alternative Multithreaded code to perform preprocessing of samples.
# This is naive multithreaded code, so use with caution. Try using
# relatively small batch sizes so that you can catch failures early.

import _thread as thread
import gc

def batch_preprocess_by_sample_index(index_list):
    for i in index_list:
        process_sample(i, preprocess_sample_onsets)
        gc.collect()
    print(f'COMPLETED PREPROCESSING SAMPLES IN {index_list}')

    
# Example of processing four batches in parallel

thread.start_new_thread(batch_preprocess_by_sample_index, (list(range(2000,2100)),) )
thread.start_new_thread(batch_preprocess_by_sample_index, (list(range(2230,2300)),) )
# Out:
# 123145572655104
# Attemping to download the following sample:
# sample_id                                  2230
# instrument_name                      Vibraphone
# note                                         D6
# expression                                  bow
# source                                 Iowa2012
# file_name          Vibraphone.bow.D6.stereo.aif
# file_extension                              aif
# Name: 0, dtype: object
# 2230.aif
# Attemping to download the following sample:
# sample_id                                               2000
# instrument_name                                    Xylophone
# note                                                     Ab4
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Ab4.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2000.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_68.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2001
# instrument_name                                   Xylophone
# note                                                     G4
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.G4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2001.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_67.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2002
# instrument_name                                   Xylophone
# note                                                     A6
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.A6.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2002.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_93.wav with offset 3693
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2003
# instrument_name                                   Xylophone
# note                                                     F5
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.F5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2003.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_77.wav with offset 1453
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2004
# instrument_name                                    Xylophone
# note                                                     Gb4
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Gb4.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2004.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_66.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2005
# instrument_name                                   Xylophone
# note                                                     C5
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.C5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2005.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_72.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2006
# instrument_name                                   Xylophone
# note                                                     E7
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.E7.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2006.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_100.wav with offset 1213
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2007
# instrument_name                                    Xylophone
# note                                                     Eb7
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Eb7.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2007.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_bow_86.wav with offset 5753
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2231
# instrument_name                             bells
# note                                           A5
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.A5.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2231.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_99.wav with offset 1197
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2008
# instrument_name                                    Xylophone
# note                                                     Bb7
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Bb7.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2008.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_106.wav with offset 1638
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2009
# instrument_name                                   Xylophone
# note                                                     C8
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.C8.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2009.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_108.wav with offset 1214
# Done!
# Attemping to download the following sample:
# sample_id                                              2010
# instrument_name                                   Xylophone
# note                                                     D6
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.D6.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2010.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_86.wav with offset 1217
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2011
# instrument_name                                   Xylophone
# note                                                     B4
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.B4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2011.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_71.wav with offset 2711
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2012
# instrument_name                                    Xylophone
# note                                                     Ab6
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Ab6.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2012.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_92.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2013
# instrument_name                                   Xylophone
# note                                                     G6
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.G6.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2013.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_91.wav with offset 1174
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2014
# instrument_name                                   Xylophone
# note                                                     A4
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.A4.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2014.aif
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_81.wav with offset 2817
# Done!
#
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Attemping to download the following sample:
# sample_id                                    2232
# instrument_name                             bells
# note                                           G7
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.G7.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2232.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_69.wav with offset 1129
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2015
# instrument_name                                    Xylophone
# note                                                     Db5
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Db5.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2015.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_103.wav with offset 2273
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2233
# instrument_name                             bells
# note                                           F6
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.F6.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2233.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_73.wav with offset 1182
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2016
# instrument_name                                   Xylophone
# note                                                     F7
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.F7.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2016.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_101.wav with offset 1471
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2017
# instrument_name                                    Xylophone
# note                                                     Eb5
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Eb5.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2017.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_75.wav with offset 1354
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2018
# instrument_name                                    Xylophone
# note                                                     Bb5
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Bb5.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2018.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_82.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                               2019
# instrument_name                                    Xylophone
# note                                                     Gb6
# expression                                  rosewood roll ff
# source                                              Iowa2012
# file_name          Xylophone.rosewood.roll.ff.Gb6.stereo.aif
# file_extension                                           aif
# Name: 0, dtype: object
# 2019.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_90.wav with offset 1066
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2020
# instrument_name                                   Xylophone
# note                                                     E5
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.E5.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2020.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_76.wav with offset 1389
# Done!
#
# Attemping to download the following sample:
# sample_id                                              2021
# instrument_name                                   Xylophone
# note                                                     B6
# expression                                 rosewood roll ff
# source                                             Iowa2012
# file_name          Xylophone.rosewood.roll.ff.B6.stereo.aif
# file_extension                                          aif
# Name: 0, dtype: object
# 2021.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Xylophone_rosewood_roll_ff_95.wav with offset 1334
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2022
# instrument_name                              Vibraphone
# note                                                Bb3
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Bb3.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2022.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_89.wav with offset 4260
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2234
# instrument_name                              bells
# note                                           Eb7
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Eb7.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2234.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_99.wav with offset 4472
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2235
# instrument_name                              bells
# note                                           Bb7
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Bb7.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2235.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_106.wav with offset 2071
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2236
# instrument_name                             bells
# note                                           C6
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.C6.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2236.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_58.wav with offset 7121
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2023
# instrument_name                              Vibraphone
# note                                                Eb3
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Eb3.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2023.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_84.wav with offset 5939
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2237
# instrument_name                             bells
# note                                           D8
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.D8.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2237.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_110.wav with offset 2115
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2238
# instrument_name                              bells
# note                                           Db7
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Db7.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2238.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_51.wav with offset 6979
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2024
# instrument_name                             Vibraphone
# note                                                D6
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.D6.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2024.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_97.wav with offset 4568
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2239
# instrument_name                             bells
# note                                           B7
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.B7.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2239.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_107.wav with offset 2703
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2240
# instrument_name                             bells
# note                                           D5
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.D5.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2240.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_74.wav with offset 3162
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2241
# instrument_name                             bells
# note                                           A7
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.A7.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2241.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_86.wav with offset 2751
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2025
# instrument_name                             Vibraphone
# note                                                A3
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.A3.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2025.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_105.wav with offset 1989
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2242
# instrument_name                             bells
# note                                           G5
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.G5.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2242.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_79.wav with offset 3925
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2243
# instrument_name                              bells
# note                                           Eb8
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Eb8.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2243.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_111.wav with offset 3234
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2244
# instrument_name                              bells
# note                                           Eb5
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Eb5.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2244.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_57.wav with offset 7835
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2026
# instrument_name                             Vibraphone
# note                                                B4
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.B4.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2026.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_75.wav with offset 1503
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2245
# instrument_name                              bells
# note                                           Bb5
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Bb5.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2245.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_82.wav with offset 2025
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2246
# instrument_name                              bells
# note                                           Gb6
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Gb6.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2246.aif
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_71.wav with offset 2178
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2027
# instrument_name                             Vibraphone
# note                                                C5
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.C5.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2027.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_90.wav with offset 4243
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2247
# instrument_name                             bells
# note                                           E6
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.E6.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2247.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_72.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2028
# instrument_name                              Vibraphone
# note                                                Ab5
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Ab5.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2028.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_88.wav with offset 3571
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2248
# instrument_name                              bells
# note                                           Db8
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Db8.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2248.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_80.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2029
# instrument_name                              Vibraphone
# note                                                Db6
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Db6.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2029.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_109.wav with offset 1678
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2249
# instrument_name                              bells
# note                                           Ab6
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Ab6.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2249.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_92.wav with offset 4813
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2250
# instrument_name                             bells
# note                                           B5
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.B5.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2250.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_85.wav with offset 2118
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2030
# instrument_name                             Vibraphone
# note                                                F5
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.F5.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2030.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_77.wav with offset 2351
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_83.wav with offset 1441
# Done!
#
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2031
# instrument_name                              Vibraphone
# note                                                Db3
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Db3.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2031.aif
# Attemping to download the following sample:
# sample_id                                    2251
# instrument_name                             bells
# note                                           D7
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.D7.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2251.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_98.wav with offset 4974
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2252
# instrument_name                              bells
# note                                           Db5
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Db5.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2252.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_73.wav with offset 2823
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2253
# instrument_name                             bells
# note                                           E5
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.E5.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2253.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_49.wav with offset 11111
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2032
# instrument_name                              Vibraphone
# note                                                Eb6
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Eb6.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2032.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_76.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2254
# instrument_name                             bells
# note                                           C7
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.C7.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2254.aif
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_87.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2033
# instrument_name                             Vibraphone
# note                                                D3
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.D3.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2033.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_96.wav with offset 4979
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2255
# instrument_name                             bells
# note                                           E8
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.E8.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2255.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_112.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2256
# instrument_name                              bells
# note                                           Db6
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Db6.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2256.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_50.wav with offset 7408
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2034
# instrument_name                             Vibraphone
# note                                                G4
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.G4.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2034.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_85.wav with offset 3499
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2257
# instrument_name                             bells
# note                                           B6
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.B6.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2257.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_95.wav with offset 2719
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2258
# instrument_name                              bells
# note                                           Ab5
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Ab5.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2258.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_67.wav with offset 1024
# Done!
#
# Attemping to download the following sample:
# sample_id                                          2035
# instrument_name                              Vibraphone
# note                                                Gb5
# expression                                   sustain ff
# source                                         Iowa2012
# file_name          Vibraphone.sustain.ff.Gb5.stereo.aif
# file_extension                                      aif
# Name: 0, dtype: object
# 2035.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_80.wav with offset 2242
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2259
# instrument_name                             bells
# note                                           G6
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.G6.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2259.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_78.wav with offset 2557
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2036
# instrument_name                             Vibraphone
# note                                                D4
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.D4.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2036.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_91.wav with offset 5565
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2260
# instrument_name                             bells
# note                                           F7
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.F7.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2260.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_101.wav with offset 4650
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2261
# instrument_name                              bells
# note                                           Gb5
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Gb5.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2261.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/Vibraphone_sustain_ff_62.wav with offset 2539
# Done!
#
# Attemping to download the following sample:
# sample_id                                         2037
# instrument_name                             Vibraphone
# note                                                G3
# expression                                  sustain ff
# source                                        Iowa2012
# file_name          Vibraphone.sustain.ff.G3.stereo.aif
# file_extension                                     aif
# Name: 0, dtype: object
# 2037.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_78.wav with offset 3205
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2262
# instrument_name                              bells
# note                                           Eb6
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Eb6.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2262.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_87.wav with offset 3534
# Done!
#
# Attemping to download the following sample:
# sample_id                                     2263
# instrument_name                              bells
# note                                           Bb6
# expression                              plastic ff
# source                                    Iowa2012
# file_name          bells.plastic.ff.Bb6.stereo.aif
# file_extension                                 aif
# Name: 0, dtype: object
# 2263.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
# Writing /Users/flatrionschool/Flatiron/Projects/sound-shift/preprocessed_samples/bells_plastic_ff_94.wav with offset 2956
# Done!
#
# Attemping to download the following sample:
# sample_id                                    2264
# instrument_name                             bells
# note                                           E7
# expression                             plastic ff
# source                                   Iowa2012
# file_name          bells.plastic.ff.E7.stereo.aif
# file_extension                                aif
# Name: 0, dtype: object
# 2264.aif
# Processing sample with <function preprocess_sample_onsets at 0x10f31f158> ...
